# %%
Parameters
index[]
columns[]
values[]

#duplicates must be removed before performing Pivot table operations
#atleast 1: qualitative, quantitative and grouping data.

# %%
import pandas as pd
df = pd.read_csv("dataset.csv")
df
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df_p = pd.pivot_table(df,index = ["diagnosis"])
df_p
# Out:
#             area_mean    area_se   area_worst  compactness_mean  \
# diagnosis
# 0          462.790196  21.135148   558.899440          0.080085
# 1          978.376415  72.672406  1422.286321          0.145188
#
#            compactness_se  compactness_worst  concave points_mean  \
# diagnosis
# 0                0.021438           0.182673             0.025717
# 1                0.032281           0.374824             0.087990
#
#            concave points_se  concave points_worst  concavity_mean  ...  \
# diagnosis                                                           ...
# 0                   0.009858              0.074444        0.046058  ...
# 1                   0.015060              0.182237        0.160775  ...
#
#            radius_worst  smoothness_mean  smoothness_se  smoothness_worst  \
# diagnosis
# 0             13.379801         0.092478       0.007196          0.124959
# 1             21.134811         0.102898       0.006780          0.144845
#
# ...

# %%
df_p1 = pd.pivot_table(df,index = ["diagnosis","radius_mean"])
df_p1
# Out:
#                        area_mean  area_se  area_worst  compactness_mean  \
# diagnosis radius_mean
# 0         6.981            143.5    9.833       185.2           0.07568
#           7.691            170.4   11.730       223.6           0.11990
#           7.729            178.8   19.140       248.0           0.04878
#           7.760            181.0   19.150       268.6           0.04362
#           8.196            201.9    8.205       242.2           0.05943
# ...                          ...      ...         ...               ...
# 1         25.220          1878.0  120.000      2562.0           0.26650
#           25.730          2010.0  153.100      3234.0           0.23630
#           27.220          2250.0  128.700      3216.0           0.19140
#           27.420          2501.0  542.200      4254.0           0.19880
#           28.110          2499.0  525.600      2499.0           0.15160
#
#                        compactness_se  compactness_worst  concave points_mean  \
# ...

# %%
df = pd.read_excel("PIVOT_iNPUT.xlsx")
df
# Out:
#                            CName            Rep        Manager  Account  \
# 0                     Barton LLC     John Smith   Debra Henley   740150
# 1   Fritsch, Russel and Anderson   Craig Booker   Debra Henley   737550
# 2                     Herman LLC    Cedric Moss  Fred Anderson   141962
# 3                  Jerde-Hilpert     John Smith   Debra Henley   412290
# 4    Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson   307599
# 5                    Keeling LLC     Wendy Yule  Fred Anderson   688981
# 6                   Kiehn-Spinka  Daniel Hilton   Debra Henley   146832
# 7                      Koepp Ltd     Wendy Yule  Fred Anderson   729833
# 8                      Kulas Inc  Daniel Hilton   Debra Henley   218895
# 9                    Purdy-Kunde    Cedric Moss  Fred Anderson   163416
# 10                    Stokes LLC    Cedric Moss  Fred Anderson   239344
# 11               Trantow-Barrows   Craig Booker   Debra Henley   714466
#
# ...

# %%
pd.pivot_table(df,index = ["CName"])  #first column should have more grouping
#don't take unique columns
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\DIJIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# ...

# %%
import numpy as np 
pd.pivot_table(df, index = ["Manager", "Rep"],values = ["Price"], aggfunc = np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    50000
#               Daniel Hilton   31500
#               John Smith      40000
# Fred Anderson Cedric Moss    107500
#               Wendy Yule     142000

# %%
pd.pivot_table(df, index = ["Manager", "Rep"],values = ["Quantity"], aggfunc = np.sum)
# Out:
#                              Quantity
# Manager       Rep
# Debra Henley  Craig Booker          2
#               Daniel Hilton         5
#               John Smith            3
# Fred Anderson Cedric Moss           4
#               Wendy Yule           10

# %% [markdown]
# 1. Create a Pivot table where the companies are listed with respect to the representative working
# 2. Identify the status of each representative working for the companies. Display the quantity sold by the representatives.
# 3. Find out the min and max sales of each representative.

# %%
pd.pivot_table(df, index = ["CName"])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\DIJIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# ...

# %%
pd.pivot_table(df, index = ["Rep"],values = ["Quantity"], aggfunc = np.sum)
# Out:
#                Quantity
# Rep
# Cedric Moss           4
# Craig Booker          2
# Daniel Hilton         5
# John Smith            3
# Wendy Yule           10

# %%
pd.pivot_table(df, index = ["Rep"],values = ["Quantity"], aggfunc = [np.sum, len])
# Out:
#                    sum      len
#               Quantity Quantity
# Rep
# Cedric Moss          4        3
# Craig Booker         2        2
# Daniel Hilton        5        2
# John Smith           3        2
# Wendy Yule          10        3

# %%
pd.pivot_table(df, index = ["Rep"],values = ["Quantity"], aggfunc = np.min)
# Out:
#                Quantity
# Rep
# Cedric Moss           1
# Craig Booker          1
# Daniel Hilton         2
# John Smith            1
# Wendy Yule            2

# %%
pd.pivot_table(df, index = ["Rep"],values = ["Quantity"], aggfunc = np.max)
# Out:
#                Quantity
# Rep
# Cedric Moss           2
# Craig Booker          1
# Daniel Hilton         3
# John Smith            2
# Wendy Yule            5

# %%
pd.pivot_table(df, index = ["Manager","Rep"],values = ["Quantity"], columns = ["Product"],aggfunc = [np.sum],fill_value=0)
# Out:
#                                  sum
#                             Quantity
# Product                          CPU HDD LAPTOP Maintenance RAM Software
# Manager       Rep
# Debra Henley  Craig Booker         0   0      0           0   0        2
#               Daniel Hilton        0   0      0           3   2        0
#               John Smith           3   0      0           0   0        0
# Fred Anderson Cedric Moss          0   0      1           2   1        0
#               Wendy Yule           3   5      2           0   0        0

# %%
pd.pivot_table(df, index = ["Manager","Rep"],values = ["Quantity","Price"], columns = ["Product"],aggfunc = [np.sum],fill_value=0)
# Out:
#                                sum                                            \
#                              Price
# Product                        CPU     HDD LAPTOP Maintenance   RAM Software
# Manager       Rep
# Debra Henley  Craig Booker       0       0      0           0     0    50000
#               Daniel Hilton      0       0      0       25000  6500        0
#               John Smith     40000       0      0           0     0        0
# Fred Anderson Cedric Moss        0       0  35000       65000  7500        0
#               Wendy Yule      7000  100000  35000           0     0        0
#
#
#                             Quantity
# Product                          CPU HDD LAPTOP Maintenance RAM Software
# Manager       Rep
# Debra Henley  Craig Booker         0   0      0           0   0        2
#               Daniel Hilton        0   0      0           3   2        0
#               John Smith           3   0      0           0   0        0
# ...

# %% [markdown]
# Under which company the representatie have sold various items. Fill the value with -1 where ever not applicable

# %%
pd.pivot_table(df, index = ["Rep", "CName"],values = ["Price"], columns = ["Product"],aggfunc = [np.sum],fill_value=-1)
# Out:
#                                               sum                             \
#                                             Price
# Product                                       CPU     HDD LAPTOP Maintenance
# Rep           CName
# Cedric Moss   Herman LLC                       -1      -1     -1       65000
#               Purdy-Kunde                      -1      -1  35000          -1
#               Stokes LLC                       -1      -1     -1          -1
# Craig Booker  Fritsch, Russel and Anderson     -1      -1     -1          -1
#               Trantow-Barrows                  -1      -1     -1          -1
# Daniel Hilton Kiehn-Spinka                     -1      -1     -1          -1
#               Kulas Inc                        -1      -1     -1       25000
# John Smith    Barton LLC                    35000      -1     -1          -1
#               Jerde-Hilpert                  5000      -1     -1          -1
# ...

# %%
pd.pivot_table(df, index = ["Manager","Rep"],values = ["Quantity","Price"], columns = ["Product"],aggfunc = [np.sum],fill_value=0)

# %%
table = pd.read_excel("PIVOT_iNPUT.xlsx")

table.query('Manager == ["Debra Henley"]')
# Out:
#                            CName            Rep       Manager  Account  \
# 0                     Barton LLC     John Smith  Debra Henley   740150
# 1   Fritsch, Russel and Anderson   Craig Booker  Debra Henley   737550
# 3                  Jerde-Hilpert     John Smith  Debra Henley   412290
# 6                   Kiehn-Spinka  Daniel Hilton  Debra Henley   146832
# 8                      Kulas Inc  Daniel Hilton  Debra Henley   218895
# 11               Trantow-Barrows   Craig Booker  Debra Henley   714466
#
#         Product  Price  Quantity      Status
# 0           CPU  35000         1  PRERSENTED
# 1      Software  35000         1  PRERSENTED
# 3           CPU   5000         2    DECLINED
# 6           RAM   6500         2  PRERSENTED
# 8   Maintenance  25000         3    DECLINED
# 11     Software  15000         1  PRERSENTED

# %% [markdown]
# Using Queries find out all the status that are executed succesfully

# %%
table.query('Status == ["PRERSENTED"]')
# Out:
#                            CName            Rep        Manager  Account  \
# 0                     Barton LLC     John Smith   Debra Henley   740150
# 1   Fritsch, Russel and Anderson   Craig Booker   Debra Henley   737550
# 5                    Keeling LLC     Wendy Yule  Fred Anderson   688981
# 6                   Kiehn-Spinka  Daniel Hilton   Debra Henley   146832
# 11               Trantow-Barrows   Craig Booker   Debra Henley   714466
#
#      Product   Price  Quantity      Status
# 0        CPU   35000         1  PRERSENTED
# 1   Software   35000         1  PRERSENTED
# 5        HDD  100000         5  PRERSENTED
# 6        RAM    6500         2  PRERSENTED
# 11  Software   15000         1  PRERSENTED

# %%
table.query('Price > 15000 ')
# Out:
#                           CName            Rep        Manager  Account  \
# 0                    Barton LLC     John Smith   Debra Henley   740150
# 1  Fritsch, Russel and Anderson   Craig Booker   Debra Henley   737550
# 2                    Herman LLC    Cedric Moss  Fred Anderson   141962
# 5                   Keeling LLC     Wendy Yule  Fred Anderson   688981
# 7                     Koepp Ltd     Wendy Yule  Fred Anderson   729833
# 8                     Kulas Inc  Daniel Hilton   Debra Henley   218895
# 9                   Purdy-Kunde    Cedric Moss  Fred Anderson   163416
#
#        Product   Price  Quantity      Status
# 0          CPU   35000         1  PRERSENTED
# 1     Software   35000         1  PRERSENTED
# 2  Maintenance   65000         2     PENDING
# 5          HDD  100000         5  PRERSENTED
# 7       LAPTOP   35000         2     PENDING
# 8  Maintenance   25000         3    DECLINED
# 9       LAPTOP   35000         1         WON

# %% [markdown]
# Idetify all the representatie not working under Debra Henley

# %%
table.query('Manager != ["Debra Henley"]')
# Out:
#                           CName          Rep        Manager  Account  \
# 2                    Herman LLC  Cedric Moss  Fred Anderson   141962
# 4   Kassulke, Ondricka and Metz   Wendy Yule  Fred Anderson   307599
# 5                   Keeling LLC   Wendy Yule  Fred Anderson   688981
# 7                     Koepp Ltd   Wendy Yule  Fred Anderson   729833
# 9                   Purdy-Kunde  Cedric Moss  Fred Anderson   163416
# 10                   Stokes LLC  Cedric Moss  Fred Anderson   239344
#
#         Product   Price  Quantity      Status
# 2   Maintenance   65000         2     PENDING
# 4           CPU    7000         3         WON
# 5           HDD  100000         5  PRERSENTED
# 7        LAPTOP   35000         2     PENDING
# 9        LAPTOP   35000         1         WON
# 10          RAM    7500         1         WON

# %% [markdown]
# 1.Perform Munging on a common column
# 2. Do the following tasks
#     a. Find which team has won the IPL maximum times.
#     b. Find the orange cap and purple cap winners in each of the series.
#     c. As a captian, find out whose performance is the best.
#        Captians performance is calculated on the following criteria.
#        (i) No fo tiems the team has reached Top 4
#        (ii) Total no of matches won/total number of matches played under his captancy
#        (iii) Captian's individual performace.
#        (iv) No. of times the captian has won the trophy
#     d. Find out who is the hard hitter in the past 10 years.(Give a list of top 3 hard hitters)
#     e. Compare and contrast the performance of RCB over any team of your choice on the following criteria
#             (i)   No of sixs
#             (ii)  No of fours
#             (iii) Centuries
#             (iv)  Half centuries
#             (v)   Hardtricks
#             (vi)  Consistent running between the wickets.
#     f. Compare and contrast any three bowlers,batters and wicket keepers belonging to each team and analyse their strength and weaknesses.
