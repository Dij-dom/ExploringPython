# %%
# importing libraries
import pandas as pd

# %%
#loading the dataset
df = pd.read_excel("Goal7.xlsx")
df
# Out:
#        Goal Target Indicator   SeriesCode  \
# 0         7    7.1     7.1.1  EG_ACS_ELEC
# 1         7    7.1     7.1.1  EG_ACS_ELEC
# 2         7    7.1     7.1.1  EG_ACS_ELEC
# 3         7    7.1     7.1.1  EG_ACS_ELEC
# 4         7    7.1     7.1.1  EG_ACS_ELEC
# ...     ...    ...       ...          ...
# 46669     7    7.b     7.b.1  EG_EGY_RNEW
# 46670     7    7.b     7.b.1  EG_EGY_RNEW
# 46671     7    7.b     7.b.1  EG_EGY_RNEW
# 46672     7    7.b     7.b.1  EG_EGY_RNEW
# 46673     7    7.b     7.b.1  EG_EGY_RNEW
#
#                                        SeriesDescription  GeoAreaCode  \
# 0      Proportion of population with access to electr...            4
# 1      Proportion of population with access to electr...            4
# 2      Proportion of population with access to electr...            4
# 3      Proportion of population with access to electr...            4
# 4      Proportion of population with access to electr...            4
# ...

# %%
# df = df[df['Target'] == '7.3']
# df
df['Target']
# Out:
# Series([], Name: Target, dtype: object)
